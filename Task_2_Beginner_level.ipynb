# %% [markdown]
# # LETSGROWMORE DATA SCIENCE INTERN TASK JUNE 2023

# %% [markdown]
# # TASK - 02

# %% [markdown]
# # Stock Market Prediction And Forecasting Using Stacked LSTM

# %% [markdown]
# By Harish Nandhan S

# %% [markdown]
# Dataset link : https://raw.githubusercontent.com/mwitiderrick/stockprice/master/NSE-TATAGLOBAL.csv

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import math
import datetime
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense , LSTM
from sklearn.metrics import mean_squared_error

# %%
data_ref_link = 'https://raw.githubusercontent.com/mwitiderrick/stockprice/master/NSE-TATAGLOBAL.csv'

# %%
df= pd.read_csv(data_ref_link, parse_dates=True,)
df.reset_index()
df.head(10)
# Out:
#          Date    Open    High     Low    Last   Close  Total Trade Quantity  \
# 0  2018-09-28  234.05  235.95  230.20  233.50  233.75               3069914
# 1  2018-09-27  234.55  236.80  231.10  233.80  233.25               5082859
# 2  2018-09-26  240.00  240.00  232.50  235.00  234.25               2240909
# 3  2018-09-25  233.30  236.75  232.00  236.25  236.10               2349368
# 4  2018-09-24  233.55  239.20  230.75  234.00  233.30               3423509
# 5  2018-09-21  235.00  237.00  227.95  233.75  234.60               5395319
# 6  2018-09-19  235.95  237.20  233.45  234.60  234.90               1362058
# 7  2018-09-18  237.90  239.25  233.50  235.50  235.05               2614794
# 8  2018-09-17  233.15  238.00  230.25  236.40  236.60               3170894
# 9  2018-09-14  223.45  236.70  223.30  234.00  233.95               6377909
#
#    Turnover (Lacs)
# 0          7162.35
# 1         11859.95
# 2          5248.60
# 3          5503.90
# 4          7999.55
# 5         12589.59
# 6          3202.78
# 7          6163.70
# 8          7445.41
# 9         14784.50

# %%
df.sample(10) 
# Returns any 10 random data points from the dataset
# Out:
#             Date    Open    High     Low    Last   Close  \
# 1856  2011-04-04  101.00  102.80  101.00  101.90  101.85
# 710   2015-11-17  129.70  134.00  128.30  133.95  132.50
# 75    2018-06-11  265.60  271.25  262.70  263.25  263.70
# 568   2016-06-15  127.25  128.15  126.60  126.75  127.00
# 1540  2012-07-09  115.00  117.85  113.65  114.25  114.15
# 1481  2012-10-03  148.90  156.50  146.25  156.25  155.40
# 1593  2012-04-25  118.65  119.40  115.30  116.70  116.65
# 1846  2011-04-20  102.00  102.95  101.15  102.00  101.80
# 1053  2014-06-24  167.45  169.50  165.50  167.00  167.30
# 434   2016-12-29  119.60  122.15  119.60  121.30  121.10
#
#       Total Trade Quantity  Turnover (Lacs)
# 1856               1054078          1075.45
# 710                1152357          1523.05
# 75                 3538690          9470.30
# 568                1662070          2116.66
# 1540               1421548          1635.53
# 1481               9645143         14680.57
# 1593               1043981          1225.18
# 1846               1089914          1110.57
# 1053               4394262          7365.66
# 434                1025503          1241.44

# %%
df.columns
# Out:
# Index(['Date', 'Open', 'High', 'Low', 'Last', 'Close', 'Total Trade Quantity',
#        'Turnover (Lacs)'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2035 entries, 0 to 2034
# Data columns (total 8 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Date                  2035 non-null   object
#  1   Open                  2035 non-null   float64
#  2   High                  2035 non-null   float64
#  3   Low                   2035 non-null   float64
#  4   Last                  2035 non-null   float64
#  5   Close                 2035 non-null   float64
#  6   Total Trade Quantity  2035 non-null   int64
#  7   Turnover (Lacs)       2035 non-null   float64
# dtypes: float64(6), int64(1), object(1)
# memory usage: 127.3+ KB

# %%
df.shape
# Out:
# (2035, 8)

# %%
df.isnull().sum()
# To check if there is any null value present in the dataset
# Out:
# Date                    0
# Open                    0
# High                    0
# Low                     0
# Last                    0
# Close                   0
# Total Trade Quantity    0
# Turnover (Lacs)         0
# dtype: int64

# %%
df.describe()
# Out:
#               Open         High          Low         Last       Close  \
# count  2035.000000  2035.000000  2035.000000  2035.000000  2035.00000
# mean    149.713735   151.992826   147.293931   149.474251   149.45027
# std      48.664509    49.413109    47.931958    48.732570    48.71204
# min      81.100000    82.800000    80.000000    81.000000    80.95000
# 25%     120.025000   122.100000   118.300000   120.075000   120.05000
# 50%     141.500000   143.400000   139.600000   141.100000   141.25000
# 75%     157.175000   159.400000   155.150000   156.925000   156.90000
# max     327.700000   328.750000   321.650000   325.950000   325.75000
#
#        Total Trade Quantity  Turnover (Lacs)
# count          2.035000e+03      2035.000000
# mean           2.335681e+06      3899.980565
# std            2.091778e+06      4570.767877
# min            3.961000e+04        37.040000
# 25%            1.146444e+06      1427.460000
# 50%            1.783456e+06      2512.030000
# 75%            2.813594e+06      4539.015000
# max            2.919102e+07     55755.080000

# %%
plt.figure(figsize=(10,6))
df['Close'].plot(kind='line',figsize=(16,7),color='b',label="Closing price")

plt.ylabel("Price")
plt.legend(loc="upper right")
plt.title("Change in Closing price over the years")
plt.grid()

# %%
plt.figure(figsize=(10,6))
df['Open'].plot(kind='line',figsize=(16,7),color='g',label="Opening Price")

plt.ylabel("Price")
plt.legend(loc="upper left")
plt.title("Change in opening price over the years")
plt.grid()

# %%
df1=df.reset_index()['Close']
df1
# Out:
# 0       233.75
# 1       233.25
# 2       234.25
# 3       236.10
# 4       233.30
#          ...
# 2030    118.65
# 2031    117.60
# 2032    120.65
# 2033    120.90
# 2034    121.55
# Name: Close, Length: 2035, dtype: float64

# %%
plt.figure(figsize=(12,6))
sns.heatmap(df.corr(),annot=True,cmap='PiYG')
# Out:
# <AxesSubplot:>

# %%
plt.figure(figsize=(11,5))
plt.subplot(1,2,1)
sns.boxplot(data=df,y='Total Trade Quantity',color='red')
plt.subplot(1,2,2)
sns.boxplot(data=df,y='Turnover (Lacs)',color='blue')
# Out:
# <AxesSubplot:ylabel='Turnover (Lacs)'>

# %%
fig=plt.figure(figsize=(7,6))
plt.scatter(df['Total Trade Quantity'],df['Turnover (Lacs)'], alpha=0.5, edgecolor='r', color='black')
plt.xlabel("Trade Quantity (in 100000)")
plt.ylabel("Turnover (in lacs)")
plt.title(" Selling Units Vs Turnover")
plt.show()

# %%
df['High'].hist()
# Out:
# <AxesSubplot:>

# %%
plt.figure(figsize=(20,8))
df.plot()
# Out:
# <AxesSubplot:>

# %%
training_set= df[['Open']]
training_set=pd.DataFrame(training_set)
training_set
# Out:
#         Open
# 0     234.05
# 1     234.55
# 2     240.00
# 3     233.30
# 4     233.55
# ...      ...
# 2030  117.60
# 2031  120.10
# 2032  121.80
# 2033  120.30
# 2034  122.10
#
# [2035 rows x 1 columns]

# %%
scaler=MinMaxScaler(feature_range=(0,1))
training_set_scaler=scaler.fit_transform(np.array(df1).reshape(-1,1))

# %%
training_set_scaler
# Out:
# array([[0.62418301],
#        [0.62214052],
#        [0.62622549],
#        ...,
#        [0.1621732 ],
#        [0.16319444],
#        [0.16584967]])

# %%
train_size1= int(len(training_set_scaler)*0.65)
test_size1=int(len(training_set_scaler))-train_size1
train_data1,test_data1=training_set_scaler[0:train_size1,:],training_set_scaler[train_size1:len(df), :1]

# %%
train_size1
# Out:
# 1322

# %%
def create_dataset(dataset,time_step=1):
    dataX, dataY = [], []
    for i in range(len(dataset)-time_step-1):
        a = dataset[i:(i+time_step), 0]   ###i=0, 0,1,2,3-----99   100 
        dataX.append(a)
        dataY.append(dataset[i + time_step, 0])
    return np.array(dataX), np.array(dataY)

# %%
time_step=100
x_train, y_train=create_dataset(train_data1, time_step)
x_test, y_test= create_dataset(test_data1, time_step)

# %%
print(x_train.shape,y_train.shape)
# Out:
# (1221, 100) (1221,)

# %%
x_test.shape
# Out:
# (612, 100)

# %%
y_test.shape
# Out:
# (612,)

# %%
x_train = x_train.reshape(x_train.shape[0],x_train.shape[1] , 1)
x_test = x_test.reshape(x_test.shape[0],x_test.shape[1] , 1)

# %%
model = Sequential()
model.add(LSTM(50, return_sequences=True, input_shape=(100,1)))
model.add(LSTM(50, return_sequences=True, input_shape=(100,1)))
model.add(LSTM(50))
model.add(Dense(1))
model.compile(loss='mean_squared_error', optimizer='adagrad', metrics='acc')

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_3 (LSTM)               (None, 100, 50)           10400
#
#  lstm_4 (LSTM)               (None, 100, 50)           20200
#
#  lstm_5 (LSTM)               (None, 50)                20200
#
#  dense_1 (Dense)             (None, 1)                 51
#
# =================================================================
# Total params: 50,851
# Trainable params: 50,851
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.fit(x_train, y_train, validation_data = (x_test, y_test), epochs = 100, batch_size = 64,verbose = 1)
# Out:
# Epoch 1/100
# 20/20 [==============================] - 18s 449ms/step - loss: 0.1021 - acc: 0.0000e+00 - val_loss: 0.0074 - val_acc: 0.0016
# Epoch 2/100
# 20/20 [==============================] - 7s 350ms/step - loss: 0.0637 - acc: 0.0000e+00 - val_loss: 0.0067 - val_acc: 0.0016
# Epoch 3/100
# 20/20 [==============================] - 7s 346ms/step - loss: 0.0458 - acc: 0.0000e+00 - val_loss: 0.0094 - val_acc: 0.0016
# Epoch 4/100
# 20/20 [==============================] - 7s 366ms/step - loss: 0.0362 - acc: 0.0000e+00 - val_loss: 0.0134 - val_acc: 0.0016
# Epoch 5/100
# 20/20 [==============================] - 7s 344ms/step - loss: 0.0302 - acc: 0.0000e+00 - val_loss: 0.0172 - val_acc: 0.0016
# Epoch 6/100
# 20/20 [==============================] - 7s 345ms/step - loss: 0.0269 - acc: 0.0000e+00 - val_loss: 0.0201 - val_acc: 0.0016
# Epoch 7/100
# 20/20 [==============================] - 7s 345ms/step - loss: 0.0250 - acc: 0.0000e+00 - val_loss: 0.0223 - val_acc: 0.0016
# Epoch 8/100
# 20/20 [==============================] - 7s 339ms/step - loss: 0.0238 - acc: 0.0000e+00 - val_loss: 0.0243 - val_acc: 0.0016
# Epoch 9/100
# 20/20 [==============================] - 7s 355ms/step - loss: 0.0228 - acc: 0.0000e+00 - val_loss: 0.0251 - val_acc: 0.0016
# Epoch 10/100
# 20/20 [==============================] - 7s 332ms/step - loss: 0.0222 - acc: 0.0000e+00 - val_loss: 0.0253 - val_acc: 0.0016
# Epoch 11/100
# 20/20 [==============================] - 7s 354ms/step - loss: 0.0216 - acc: 0.0000e+00 - val_loss: 0.0259 - val_acc: 0.0016
# Epoch 12/100
# 20/20 [==============================] - 7s 336ms/step - loss: 0.0211 - acc: 0.0000e+00 - val_loss: 0.0263 - val_acc: 0.0016
# Epoch 13/100
# 20/20 [==============================] - 7s 338ms/step - loss: 0.0205 - acc: 0.0000e+00 - val_loss: 0.0257 - val_acc: 0.0016
# Epoch 14/100
# 20/20 [==============================] - 7s 334ms/step - loss: 0.0201 - acc: 0.0000e+00 - val_loss: 0.0255 - val_acc: 0.0016
# Epoch 15/100
# 20/20 [==============================] - 7s 338ms/step - loss: 0.0196 - acc: 0.0000e+00 - val_loss: 0.0246 - val_acc: 0.0016
# Epoch 16/100
# 20/20 [==============================] - 7s 348ms/step - loss: 0.0192 - acc: 0.0000e+00 - val_loss: 0.0239 - val_acc: 0.0016
# Epoch 17/100
# 20/20 [==============================] - 7s 352ms/step - loss: 0.0187 - acc: 0.0000e+00 - val_loss: 0.0232 - val_acc: 0.0016
# Epoch 18/100
# 20/20 [==============================] - 7s 340ms/step - loss: 0.0183 - acc: 0.0000e+00 - val_loss: 0.0224 - val_acc: 0.0016
# Epoch 19/100
# 20/20 [==============================] - 7s 362ms/step - loss: 0.0179 - acc: 0.0000e+00 - val_loss: 0.0224 - val_acc: 0.0016
# Epoch 20/100
# 20/20 [==============================] - 7s 361ms/step - loss: 0.0174 - acc: 0.0000e+00 - val_loss: 0.0215 - val_acc: 0.0016
# Epoch 21/100
# 20/20 [==============================] - 7s 375ms/step - loss: 0.0170 - acc: 0.0000e+00 - val_loss: 0.0212 - val_acc: 0.0016
# Epoch 22/100
# 20/20 [==============================] - 7s 374ms/step - loss: 0.0165 - acc: 0.0000e+00 - val_loss: 0.0214 - val_acc: 0.0016
# Epoch 23/100
# 20/20 [==============================] - 7s 370ms/step - loss: 0.0161 - acc: 8.1900e-04 - val_loss: 0.0209 - val_acc: 0.0016
# Epoch 24/100
# 20/20 [==============================] - 7s 361ms/step - loss: 0.0156 - acc: 8.1900e-04 - val_loss: 0.0197 - val_acc: 0.0016
# Epoch 25/100
# 20/20 [==============================] - 7s 367ms/step - loss: 0.0152 - acc: 8.1900e-04 - val_loss: 0.0188 - val_acc: 0.0016
# Epoch 26/100
# 20/20 [==============================] - 7s 350ms/step - loss: 0.0148 - acc: 8.1900e-04 - val_loss: 0.0179 - val_acc: 0.0016
# Epoch 27/100
# 20/20 [==============================] - 7s 337ms/step - loss: 0.0144 - acc: 8.1900e-04 - val_loss: 0.0172 - val_acc: 0.0016
# Epoch 28/100
# 20/20 [==============================] - 7s 373ms/step - loss: 0.0140 - acc: 8.1900e-04 - val_loss: 0.0166 - val_acc: 0.0016
# Epoch 29/100
# 20/20 [==============================] - 7s 359ms/step - loss: 0.0136 - acc: 8.1900e-04 - val_loss: 0.0162 - val_acc: 0.0016
# Epoch 30/100
# 20/20 [==============================] - 7s 346ms/step - loss: 0.0132 - acc: 8.1900e-04 - val_loss: 0.0158 - val_acc: 0.0016
# Epoch 31/100
# 20/20 [==============================] - 7s 365ms/step - loss: 0.0129 - acc: 8.1900e-04 - val_loss: 0.0153 - val_acc: 0.0016
# Epoch 32/100
# 20/20 [==============================] - 7s 355ms/step - loss: 0.0125 - acc: 8.1900e-04 - val_loss: 0.0146 - val_acc: 0.0016
# Epoch 33/100
# 20/20 [==============================] - 7s 349ms/step - loss: 0.0121 - acc: 8.1900e-04 - val_loss: 0.0140 - val_acc: 0.0016
# Epoch 34/100
# 20/20 [==============================] - 7s 337ms/step - loss: 0.0118 - acc: 8.1900e-04 - val_loss: 0.0135 - val_acc: 0.0016
# Epoch 35/100
# 20/20 [==============================] - 7s 343ms/step - loss: 0.0114 - acc: 8.1900e-04 - val_loss: 0.0132 - val_acc: 0.0016
# Epoch 36/100
# 20/20 [==============================] - 7s 347ms/step - loss: 0.0110 - acc: 8.1900e-04 - val_loss: 0.0125 - val_acc: 0.0016
# Epoch 37/100
# 20/20 [==============================] - 7s 344ms/step - loss: 0.0107 - acc: 8.1900e-04 - val_loss: 0.0121 - val_acc: 0.0016
# Epoch 38/100
# 20/20 [==============================] - 7s 366ms/step - loss: 0.0103 - acc: 8.1900e-04 - val_loss: 0.0113 - val_acc: 0.0016
# Epoch 39/100
# 20/20 [==============================] - 7s 368ms/step - loss: 0.0100 - acc: 8.1900e-04 - val_loss: 0.0107 - val_acc: 0.0016
# Epoch 40/100
# 20/20 [==============================] - 7s 334ms/step - loss: 0.0097 - acc: 8.1900e-04 - val_loss: 0.0105 - val_acc: 0.0016
# Epoch 41/100
# 20/20 [==============================] - 7s 362ms/step - loss: 0.0094 - acc: 8.1900e-04 - val_loss: 0.0099 - val_acc: 0.0016
# Epoch 42/100
# 20/20 [==============================] - 7s 345ms/step - loss: 0.0090 - acc: 8.1900e-04 - val_loss: 0.0094 - val_acc: 0.0016
# Epoch 43/100
# 20/20 [==============================] - 7s 339ms/step - loss: 0.0087 - acc: 8.1900e-04 - val_loss: 0.0088 - val_acc: 0.0016
# Epoch 44/100
# 20/20 [==============================] - 7s 339ms/step - loss: 0.0085 - acc: 8.1900e-04 - val_loss: 0.0084 - val_acc: 0.0016
# Epoch 45/100
# 20/20 [==============================] - 7s 358ms/step - loss: 0.0082 - acc: 8.1900e-04 - val_loss: 0.0081 - val_acc: 0.0016
# Epoch 46/100
# 20/20 [==============================] - 7s 363ms/step - loss: 0.0079 - acc: 8.1900e-04 - val_loss: 0.0077 - val_acc: 0.0016
# Epoch 47/100
# 20/20 [==============================] - 7s 368ms/step - loss: 0.0076 - acc: 8.1900e-04 - val_loss: 0.0074 - val_acc: 0.0016
# Epoch 48/100
# 20/20 [==============================] - 7s 358ms/step - loss: 0.0074 - acc: 8.1900e-04 - val_loss: 0.0069 - val_acc: 0.0016
# Epoch 49/100
# 20/20 [==============================] - 7s 365ms/step - loss: 0.0071 - acc: 8.1900e-04 - val_loss: 0.0065 - val_acc: 0.0016
# Epoch 50/100
# 20/20 [==============================] - 7s 362ms/step - loss: 0.0069 - acc: 8.1900e-04 - val_loss: 0.0061 - val_acc: 0.0016
# Epoch 51/100
# 20/20 [==============================] - 7s 356ms/step - loss: 0.0066 - acc: 8.1900e-04 - val_loss: 0.0058 - val_acc: 0.0016
# Epoch 52/100
# 20/20 [==============================] - 7s 359ms/step - loss: 0.0064 - acc: 8.1900e-04 - val_loss: 0.0055 - val_acc: 0.0016
# Epoch 53/100
# 20/20 [==============================] - 7s 370ms/step - loss: 0.0062 - acc: 8.1900e-04 - val_loss: 0.0052 - val_acc: 0.0016
# Epoch 54/100
# 20/20 [==============================] - 7s 367ms/step - loss: 0.0060 - acc: 8.1900e-04 - val_loss: 0.0051 - val_acc: 0.0016
# Epoch 55/100
# 20/20 [==============================] - 7s 370ms/step - loss: 0.0057 - acc: 8.1900e-04 - val_loss: 0.0048 - val_acc: 0.0016
# Epoch 56/100
# 20/20 [==============================] - 7s 346ms/step - loss: 0.0055 - acc: 8.1900e-04 - val_loss: 0.0044 - val_acc: 0.0016
# Epoch 57/100
# 20/20 [==============================] - 7s 368ms/step - loss: 0.0053 - acc: 8.1900e-04 - val_loss: 0.0042 - val_acc: 0.0016
# Epoch 58/100
# 20/20 [==============================] - 8s 380ms/step - loss: 0.0052 - acc: 8.1900e-04 - val_loss: 0.0040 - val_acc: 0.0016
# Epoch 59/100
# 20/20 [==============================] - 7s 371ms/step - loss: 0.0050 - acc: 8.1900e-04 - val_loss: 0.0037 - val_acc: 0.0016
# Epoch 60/100
# 20/20 [==============================] - 7s 358ms/step - loss: 0.0048 - acc: 8.1900e-04 - val_loss: 0.0035 - val_acc: 0.0016
# Epoch 61/100
# 20/20 [==============================] - 6s 322ms/step - loss: 0.0047 - acc: 8.1900e-04 - val_loss: 0.0033 - val_acc: 0.0016
# Epoch 62/100
# 20/20 [==============================] - 7s 333ms/step - loss: 0.0045 - acc: 8.1900e-04 - val_loss: 0.0031 - val_acc: 0.0016
# Epoch 63/100
# 20/20 [==============================] - 7s 340ms/step - loss: 0.0044 - acc: 8.1900e-04 - val_loss: 0.0031 - val_acc: 0.0016
# Epoch 64/100
# 20/20 [==============================] - 7s 333ms/step - loss: 0.0042 - acc: 8.1900e-04 - val_loss: 0.0029 - val_acc: 0.0016
# Epoch 65/100
# 20/20 [==============================] - 7s 353ms/step - loss: 0.0041 - acc: 8.1900e-04 - val_loss: 0.0026 - val_acc: 0.0016
# Epoch 66/100
# 20/20 [==============================] - 7s 339ms/step - loss: 0.0039 - acc: 8.1900e-04 - val_loss: 0.0025 - val_acc: 0.0016
# Epoch 67/100
# 20/20 [==============================] - 6s 325ms/step - loss: 0.0038 - acc: 8.1900e-04 - val_loss: 0.0024 - val_acc: 0.0016
# Epoch 68/100
# 20/20 [==============================] - 6s 324ms/step - loss: 0.0037 - acc: 8.1900e-04 - val_loss: 0.0023 - val_acc: 0.0016
# Epoch 69/100
# 20/20 [==============================] - 7s 343ms/step - loss: 0.0036 - acc: 8.1900e-04 - val_loss: 0.0021 - val_acc: 0.0016
# Epoch 70/100
# 20/20 [==============================] - 7s 336ms/step - loss: 0.0035 - acc: 8.1900e-04 - val_loss: 0.0019 - val_acc: 0.0016
# Epoch 71/100
# 20/20 [==============================] - 7s 342ms/step - loss: 0.0034 - acc: 8.1900e-04 - val_loss: 0.0018 - val_acc: 0.0016
# Epoch 72/100
# 20/20 [==============================] - 7s 336ms/step - loss: 0.0033 - acc: 8.1900e-04 - val_loss: 0.0018 - val_acc: 0.0016
# Epoch 73/100
# 20/20 [==============================] - 7s 337ms/step - loss: 0.0032 - acc: 8.1900e-04 - val_loss: 0.0017 - val_acc: 0.0016
# Epoch 74/100
# 20/20 [==============================] - 7s 375ms/step - loss: 0.0032 - acc: 8.1900e-04 - val_loss: 0.0016 - val_acc: 0.0016
# Epoch 75/100
# 20/20 [==============================] - 7s 328ms/step - loss: 0.0031 - acc: 8.1900e-04 - val_loss: 0.0016 - val_acc: 0.0016
# Epoch 76/100
# 20/20 [==============================] - 7s 338ms/step - loss: 0.0030 - acc: 8.1900e-04 - val_loss: 0.0014 - val_acc: 0.0016
# Epoch 77/100
# 20/20 [==============================] - 6s 323ms/step - loss: 0.0029 - acc: 8.1900e-04 - val_loss: 0.0014 - val_acc: 0.0016
# Epoch 78/100
# 20/20 [==============================] - 7s 342ms/step - loss: 0.0029 - acc: 8.1900e-04 - val_loss: 0.0013 - val_acc: 0.0016
# Epoch 79/100
# 20/20 [==============================] - 7s 343ms/step - loss: 0.0028 - acc: 8.1900e-04 - val_loss: 0.0013 - val_acc: 0.0016
# Epoch 80/100
# 20/20 [==============================] - 7s 335ms/step - loss: 0.0028 - acc: 8.1900e-04 - val_loss: 0.0013 - val_acc: 0.0016
# Epoch 81/100
# 20/20 [==============================] - 7s 342ms/step - loss: 0.0027 - acc: 8.1900e-04 - val_loss: 0.0012 - val_acc: 0.0016
# Epoch 82/100
# 20/20 [==============================] - 7s 339ms/step - loss: 0.0027 - acc: 8.1900e-04 - val_loss: 0.0012 - val_acc: 0.0016
# Epoch 83/100
# 20/20 [==============================] - 7s 353ms/step - loss: 0.0027 - acc: 8.1900e-04 - val_loss: 0.0011 - val_acc: 0.0016
# Epoch 84/100
# 20/20 [==============================] - 7s 340ms/step - loss: 0.0026 - acc: 8.1900e-04 - val_loss: 0.0011 - val_acc: 0.0016
# Epoch 85/100
# 20/20 [==============================] - 6s 325ms/step - loss: 0.0026 - acc: 8.1900e-04 - val_loss: 0.0011 - val_acc: 0.0016
# Epoch 86/100
# 20/20 [==============================] - 7s 334ms/step - loss: 0.0026 - acc: 8.1900e-04 - val_loss: 0.0011 - val_acc: 0.0016
# Epoch 87/100
# 20/20 [==============================] - 7s 336ms/step - loss: 0.0025 - acc: 8.1900e-04 - val_loss: 0.0011 - val_acc: 0.0016
# Epoch 88/100
# 20/20 [==============================] - 7s 336ms/step - loss: 0.0025 - acc: 8.1900e-04 - val_loss: 0.0010 - val_acc: 0.0016
# Epoch 89/100
# 20/20 [==============================] - 7s 338ms/step - loss: 0.0025 - acc: 8.1900e-04 - val_loss: 0.0010 - val_acc: 0.0016
# Epoch 90/100
# 20/20 [==============================] - 7s 338ms/step - loss: 0.0025 - acc: 8.1900e-04 - val_loss: 0.0010 - val_acc: 0.0016
# Epoch 91/100
# 20/20 [==============================] - 7s 348ms/step - loss: 0.0024 - acc: 8.1900e-04 - val_loss: 0.0010 - val_acc: 0.0016
# Epoch 92/100
# 20/20 [==============================] - 7s 336ms/step - loss: 0.0024 - acc: 8.1900e-04 - val_loss: 0.0010 - val_acc: 0.0016
# Epoch 93/100
# 20/20 [==============================] - 6s 322ms/step - loss: 0.0024 - acc: 8.1900e-04 - val_loss: 0.0010 - val_acc: 0.0016
# Epoch 94/100
# 20/20 [==============================] - 7s 344ms/step - loss: 0.0024 - acc: 8.1900e-04 - val_loss: 0.0010 - val_acc: 0.0016
# Epoch 95/100
# 20/20 [==============================] - 7s 346ms/step - loss: 0.0024 - acc: 8.1900e-04 - val_loss: 9.8957e-04 - val_acc: 0.0016
# Epoch 96/100
# 20/20 [==============================] - 7s 342ms/step - loss: 0.0024 - acc: 8.1900e-04 - val_loss: 9.8970e-04 - val_acc: 0.0016
# Epoch 97/100
# 20/20 [==============================] - 7s 351ms/step - loss: 0.0023 - acc: 8.1900e-04 - val_loss: 9.8066e-04 - val_acc: 0.0016
# Epoch 98/100
# 20/20 [==============================] - 7s 342ms/step - loss: 0.0023 - acc: 8.1900e-04 - val_loss: 9.9188e-04 - val_acc: 0.0016
# Epoch 99/100
# 20/20 [==============================] - 7s 354ms/step - loss: 0.0023 - acc: 8.1900e-04 - val_loss: 9.8122e-04 - val_acc: 0.0016
# Epoch 100/100
# 20/20 [==============================] - 7s 353ms/step - loss: 0.0023 - acc: 8.1900e-04 - val_loss: 9.8771e-04 - val_acc: 0.0016

# %%
train_predict1=model.predict(x_train)
test_predict1=model.predict(x_test)

#Transform again to original form

train_predict1=scaler.inverse_transform(train_predict1)
test_predict1=scaler.inverse_transform(test_predict1)
# Out:
# 39/39 [==============================] - 5s 80ms/step
# 20/20 [==============================] - 1s 68ms/step

# %%
math.sqrt(mean_squared_error(y_train,train_predict1))
# Out:
# 165.04657126146287

# %%
math.sqrt(mean_squared_error(y_test,test_predict1))
# Out:
# 115.6571270666443

# %%
### Plotting 

# shift train predictions for plotting
look_back=100
trainPredictPlot = np.empty_like(training_set_scaler)
trainPredictPlot[:, :] = np.nan
trainPredictPlot[look_back:len(train_predict1)+look_back, :] = train_predict1

# shift test predictions for plotting
testPredictPlot = np.empty_like(training_set_scaler)
testPredictPlot[:, :] = np.nan
testPredictPlot[len(train_predict1)+(look_back*2)+1:len(df1)-1, :] = test_predict1

# plot baseline and predictions
plt.figure(figsize=(10,5))
plt.plot(scaler.inverse_transform(training_set_scaler))
plt.plot(trainPredictPlot)
plt.plot(testPredictPlot)
plt.show()
